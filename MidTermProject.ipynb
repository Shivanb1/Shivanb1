# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv('/Users/shivanireddy/Downloads/winequality (1).csv')
df.shape
# Out:
# (1599, 12)

# %%
 df.head()
# Out:
#    fixedacidity  volatileacidity  citricacid  residualsugar  chlorides  \
# 0           7.4             0.70        0.00            1.9      0.076
# 1           7.8             0.88        0.00            2.6      0.098
# 2           7.8             0.76        0.04            2.3      0.092
# 3          11.2             0.28        0.56            1.9      0.075
# 4           7.4             0.70        0.00            1.9      0.076
#
#    freesulfurdioxide  totalsulfurdioxide  density    pH  sulphates  alcohol  \
# 0               11.0                34.0   0.9978  3.51       0.56      9.4
# 1               25.0                67.0   0.9968  3.20       0.68      9.8
# 2               15.0                54.0   0.9970  3.26       0.65      9.8
# 3               17.0                60.0   0.9980  3.16       0.58      9.8
# 4               11.0                34.0   0.9978  3.51       0.56      9.4
#
#    quality
# 0        5
# 1        5
# 2        5
# 3        6
# 4        5

# %%
df
# Out:
#       fixedacidity  volatileacidity  citricacid  residualsugar  chlorides  \
# 0              7.4            0.700        0.00            1.9      0.076
# 1              7.8            0.880        0.00            2.6      0.098
# 2              7.8            0.760        0.04            2.3      0.092
# 3             11.2            0.280        0.56            1.9      0.075
# 4              7.4            0.700        0.00            1.9      0.076
# ...            ...              ...         ...            ...        ...
# 1594           6.2            0.600        0.08            2.0      0.090
# 1595           5.9            0.550        0.10            2.2      0.062
# 1596           6.3            0.510        0.13            2.3      0.076
# 1597           5.9            0.645        0.12            2.0      0.075
# 1598           6.0            0.310        0.47            3.6      0.067
#
#       freesulfurdioxide  totalsulfurdioxide  density    pH  sulphates  \
# ...

# %%
df_ph=df.sort_values(['pH'],ascending=False)

# %%
df_ph1=df_ph[0:10]
df_ph1
# Out:
#       fixedacidity  volatileacidity  citricacid  residualsugar  chlorides  \
# 1316           5.4            0.740        0.00           1.20      0.041
# 1321           5.0            0.740        0.00           1.20      0.041
# 695            5.1            0.470        0.02           1.30      0.034
# 45             4.6            0.520        0.15           2.10      0.054
# 95             4.7            0.600        0.17           2.30      0.058
# 1300           5.2            0.645        0.00           2.15      0.080
# 1111           5.4            0.420        0.27           2.00      0.092
# 94             5.0            1.020        0.04           1.40      0.045
# 553            5.0            1.040        0.24           1.60      0.050
# 1491           5.6            0.540        0.04           1.70      0.049
#
#       freesulfurdioxide  totalsulfurdioxide  density    pH  sulphates  \
# 1316               16.0                46.0  0.99258  4.01       0.59
# ...

# %%
df_ph1['pH'].plot(kind='bar', figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
df_alcohol= df.sort_values(['alcohol'],ascending=False)
df_alcohol
# Out:
#       fixedacidity  volatileacidity  citricacid  residualsugar  chlorides  \
# 652           15.9             0.36        0.65            7.5      0.096
# 588            5.0             0.42        0.24            2.0      0.060
# 142            5.2             0.34        0.00            1.8      0.050
# 144            5.2             0.34        0.00            1.8      0.050
# 1270           5.0             0.38        0.01            1.6      0.048
# ...            ...              ...         ...            ...        ...
# 371            7.9             0.24        0.40            1.6      0.056
# 528            8.2             0.42        0.49            2.6      0.084
# 1436          10.0             0.38        0.38            1.6      0.169
# 544           14.3             0.31        0.74            1.8      0.075
# 517           10.4             0.61        0.49            2.1      0.200
#
#       freesulfurdioxide  totalsulfurdioxide  density    pH  sulphates  \
# ...

# %%
df_alcohol['alcohol'][0:10].plot(kind='bar',figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#       fixedacidity  volatileacidity  citricacid  residualsugar  chlorides  \
# 0              7.4            0.700        0.00            1.9      0.076
# 1              7.8            0.880        0.00            2.6      0.098
# 2              7.8            0.760        0.04            2.3      0.092
# 3             11.2            0.280        0.56            1.9      0.075
# 4              7.4            0.700        0.00            1.9      0.076
# ...            ...              ...         ...            ...        ...
# 1594           6.2            0.600        0.08            2.0      0.090
# 1595           5.9            0.550        0.10            2.2      0.062
# 1596           6.3            0.510        0.13            2.3      0.076
# 1597           5.9            0.645        0.12            2.0      0.075
# 1598           6.0            0.310        0.47            3.6      0.067
#
#       freesulfurdioxide  totalsulfurdioxide  density    pH  sulphates  \
# ...

# %%
df_sulphates=df.sort_values(['sulphates'],ascending=False)

# %%
df_sulphates
# Out:
#       fixedacidity  volatileacidity  citricacid  residualsugar  chlorides  \
# 151            9.2            0.520        1.00           3.40      0.610
# 92             8.6            0.490        0.29           2.00      0.110
# 91             8.6            0.490        0.28           1.90      0.110
# 86             8.6            0.490        0.28           1.90      0.110
# 723            7.1            0.310        0.30           2.20      0.053
# ...            ...              ...         ...            ...        ...
# 65             7.2            0.725        0.05           4.65      0.086
# 1348           7.2            0.655        0.03           1.80      0.078
# 1369           6.6            0.610        0.00           1.60      0.069
# 1287           8.0            0.600        0.08           2.60      0.056
# 170            7.9            0.885        0.03           1.80      0.058
#
#       freesulfurdioxide  totalsulfurdioxide  density    pH  sulphates  \
# ...

# %%
df_sulphates['sulphates'][0:10].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        fixedacidity  volatileacidity   citricacid  residualsugar    chlorides  \
# count   1599.000000      1599.000000  1599.000000    1599.000000  1599.000000
# mean       8.319637         0.527821     0.270976       2.538806     0.087467
# std        1.741096         0.179060     0.194801       1.409928     0.047065
# min        4.600000         0.120000     0.000000       0.900000     0.012000
# 25%        7.100000         0.390000     0.090000       1.900000     0.070000
# 50%        7.900000         0.520000     0.260000       2.200000     0.079000
# 75%        9.200000         0.640000     0.420000       2.600000     0.090000
# max       15.900000         1.580000     1.000000      15.500000     0.611000
#
#        freesulfurdioxide  totalsulfurdioxide      density           pH  \
# count        1599.000000         1599.000000  1599.000000  1599.000000
# mean           15.874922           46.467792     0.996747     3.311113
# ...

# %%
df[]

# %%
df.dtypes
# Out:
# fixedacidity          float64
# volatileacidity       float64
# citricacid            float64
# residualsugar         float64
# chlorides             float64
# freesulfurdioxide     float64
# totalsulfurdioxide    float64
# density               float64
# pH                    float64
# sulphates             float64
# alcohol               float64
# quality                 int64
# dtype: object

# %%
df.nunique()
# Out:
# fixedacidity           96
# volatileacidity       143
# citricacid             80
# residualsugar          91
# chlorides             153
# freesulfurdioxide      60
# totalsulfurdioxide    144
# density               436
# pH                     89
# sulphates              96
# alcohol                65
# quality                 6
# dtype: int64

# %%
df['alcohol'].unique()
# Out:
# array([ 9.4       ,  9.8       , 10.        ,  9.5       , 10.5       ,
#         9.2       ,  9.9       ,  9.1       ,  9.3       ,  9.        ,
#         9.7       , 10.1       , 10.6       ,  9.6       , 10.8       ,
#        10.3       , 13.1       , 10.2       , 10.9       , 10.7       ,
#        12.9       , 10.4       , 13.        , 14.        , 11.5       ,
#        11.4       , 12.4       , 11.        , 12.2       , 12.8       ,
#        12.6       , 12.5       , 11.7       , 11.3       , 12.3       ,
#        12.        , 11.9       , 11.8       ,  8.7       , 13.3       ,
#        11.2       , 11.6       , 11.1       , 13.4       , 12.1       ,
#         8.4       , 12.7       , 14.9       , 13.2       , 13.6       ,
#        13.5       , 10.03333333,  9.55      ,  8.5       , 11.06666667,
#         9.56666667, 10.55      ,  8.8       , 13.56666667, 11.95      ,
#         9.95      ,  9.23333333,  9.25      ,  9.05      , 10.75      ])

# %%
plt.plot(df['fixedacidity'])

# %%
df.boxplot(column='fixedacidity')
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column='volatileacidity')
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column='citricacid')
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column='residualsugar')
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column='chlorides')
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column='freesulfurdioxide')
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column='totalsulfurdioxide')
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column='density')
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column='pH')
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column='sulphates')
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column='alcohol')
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        fixedacidity  volatileacidity   citricacid  residualsugar    chlorides  \
# count   1599.000000      1599.000000  1599.000000    1599.000000  1599.000000
# mean       8.319637         0.527821     0.270976       2.538806     0.087467
# std        1.741096         0.179060     0.194801       1.409928     0.047065
# min        4.600000         0.120000     0.000000       0.900000     0.012000
# 25%        7.100000         0.390000     0.090000       1.900000     0.070000
# 50%        7.900000         0.520000     0.260000       2.200000     0.079000
# 75%        9.200000         0.640000     0.420000       2.600000     0.090000
# max       15.900000         1.580000     1.000000      15.500000     0.611000
#
#        freesulfurdioxide  totalsulfurdioxide      density           pH  \
# count        1599.000000         1599.000000  1599.000000  1599.000000
# mean           15.874922           46.467792     0.996747     3.311113
# ...

# %%
df.isnull().any()
# Out:
# fixedacidity          False
# volatileacidity       False
# citricacid            False
# residualsugar         False
# chlorides             False
# freesulfurdioxide     False
# totalsulfurdioxide    False
# density               False
# pH                    False
# sulphates             False
# alcohol               False
# quality               False
# dtype: bool

# %%
df.corr()
# Out:
#                     fixedacidity  volatileacidity  citricacid  residualsugar  \
# fixedacidity            1.000000        -0.256131    0.671703       0.114777
# volatileacidity        -0.256131         1.000000   -0.552496       0.001918
# citricacid              0.671703        -0.552496    1.000000       0.143577
# residualsugar           0.114777         0.001918    0.143577       1.000000
# chlorides               0.093705         0.061298    0.203823       0.055610
# freesulfurdioxide      -0.153794        -0.010504   -0.060978       0.187049
# totalsulfurdioxide     -0.113181         0.076470    0.035533       0.203028
# density                 0.668047         0.022026    0.364947       0.355283
# pH                     -0.682978         0.234937   -0.541904      -0.085652
# sulphates               0.183006        -0.260987    0.312770       0.005527
# alcohol                -0.061668        -0.202288    0.109903       0.042075
# ...

# %%
k=12
cols=df.corr().nlargest(k,"quality")["quality"].index
cm=df[cols].corr()
plt.figure(figsize=(10,6))
sns.heatmap(cm,annot=True,cmap="viridis")
# Out:
# <AxesSubplot:>

# %%
X=df.drop(['quality'],axis=1)
y=df['quality']

# %%
from sklearn.preprocessing import Normalizer
transformed=Normalizer().transform(df).reshape(1599,12)
normalized_a2=pd.DataFrame(transformed,columns=df.columns)
normalized_a2
# Out:
#       fixedacidity  volatileacidity  citricacid  residualsugar  chlorides  \
# 0         0.193478         0.018302    0.000000       0.049677   0.001987
# 1         0.106989         0.012071    0.000000       0.035663   0.001344
# 2         0.134949         0.013149    0.000692       0.039793   0.001592
# 3         0.173611         0.004340    0.008681       0.029452   0.001163
# 4         0.193478         0.018302    0.000000       0.049677   0.001987
# ...            ...              ...         ...            ...        ...
# 1594      0.110445         0.010688    0.001425       0.035628   0.001603
# 1595      0.089586         0.008351    0.001518       0.033405   0.000941
# 1596      0.122232         0.009895    0.002522       0.044624   0.001475
# 1597      0.105248         0.011506    0.002141       0.035677   0.001338
# 1598      0.124913         0.006454    0.009785       0.074948   0.001395
#
#       freesulfurdioxide  totalsulfurdioxide   density        pH  sulphates  \
# ...

# %%
q2=normalized_a2['quality']
a2=normalized_a2[['alcohol','sulphates','citricacid','fixedacidity','residualsugar','freesulfurdioxide','pH','chlorides','density','totalsulfurdioxide','volatileacidity']]

# %%
normalized_a2.describe()
# Out:
#        fixedacidity  volatileacidity   citricacid  residualsugar    chlorides  \
# count   1599.000000      1599.000000  1599.000000    1599.000000  1599.000000
# mean       0.215313         0.013444     0.006922       0.062610     0.002210
# std        0.123825         0.009042     0.006969       0.043870     0.001614
# min        0.027054         0.001027     0.000000       0.007761     0.000112
# 25%        0.114058         0.007056     0.001896       0.033486     0.001156
# 50%        0.183688         0.011177     0.004321       0.052861     0.001865
# 75%        0.296968         0.017290     0.010001       0.077837     0.002762
# max        0.661059         0.089465     0.035993       0.480944     0.018949
#
#        freesulfurdioxide  totalsulfurdioxide      density           pH  \
# count        1599.000000         1599.000000  1599.000000  1599.000000
# mean            0.305282            0.823186     0.025545     0.084877
# ...

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/Users/shivanireddy/Downloads/winequality (1).csv')
X = df.iloc[:,0:11] 
y = df.iloc[:,-1]    
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,y)
print(model.feature_importances_) 
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(11).plot(kind='barh')
plt.show()
# Out:
# [0.07524832 0.097038   0.08078304 0.07743844 0.07769347 0.07424619
#  0.10265091 0.08545805 0.07703554 0.10638719 0.14602087]

# %%
qq='quality'
Y=normalized_a2.loc[:,'quality']
for i in normalized_a2.columns:
    plt.figure()
    sns.regplot(x=i,y=qq,data=normalized_a2,color='g')
    plt.xlabel(i)
    plt.ylabel(qq)

# %% [markdown]
# ####The observations extracted from the above information are:
# According to the bar grpah plotted above:
# The highest pH level is observed at 1316.
# The highest level of suplates are found at 151.
# The highest consumption is recorded to be alcohol.

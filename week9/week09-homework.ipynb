# %% [markdown]
# # Week9 Homework
# ## Working with Strings
#
# The data frame contains notes taken by staff members. Your task is to clean it up to make it usable for analysis.
#
# ### Tasks
# * Create start date, end date columns and populate the values (If notes don't include month or day use 1) i.e: 2018 => 2018-01-01
#
# * Create phone number column (If notes don't include phone numbers, use None)
# * Create a column `duration` showing difference between start & end dates in years as a whole number

# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/shivanireddy/Downloads/hw_data.csv', index_col=0)

# %%
df.head()
# Out:
#                            email  \
# 0       fosterjennifer@gmail.com
# 1      vanessastephens@gmail.com
# 2               vsmith@yahoo.com
# 3          tammymorgan@gmail.com
# 4  kimberlylyons@mason-solis.biz
#
#                                                notes
# 0               st Dt February 2005 ed dt;10/27/2011
# 1  st date:1974-05-21 end date 06/17/2013 pn:  00...
# 2             start dt 01/14/1985-ed date:2021-03-21
# 3                   STDT July 1973-end dt 01/20/2012
# 4    st date:09/28/2002-ENDT 04/10-p/n  929-878-4923

# %%
df
# Out:
#                               email  \
# 0          fosterjennifer@gmail.com
# 1         vanessastephens@gmail.com
# 2                  vsmith@yahoo.com
# 3             tammymorgan@gmail.com
# 4     kimberlylyons@mason-solis.biz
# ...                             ...
# 1995           linblake@hotmail.com
# 1996             xgriffin@gmail.com
# 1997   alexanderrodriguez@smith.com
# 1998            wwilliams@yahoo.com
# 1999              brent46@gmail.com
#
#                                                   notes
# 0                  st Dt February 2005 ed dt;10/27/2011
# 1     st date:1974-05-21 end date 06/17/2013 pn:  00...
# 2                start dt 01/14/1985-ed date:2021-03-21
# 3                      STDT July 1973-end dt 01/20/2012
# 4       st date:09/28/2002-ENDT 04/10-p/n  929-878-4923
# ...                                                 ...
# 1995  st dt;1988-03-28 end date 04/10 pn: 866.901.29...
# 1996             P# 9478756534 st Dt 01/97 end Dt 05/11
# ...

# %%
import pandas as pd
import re
#df = pd.read_csv('https://raw.githubusercontent.com/msaricaumbc/DS601_Fall21/main/Week09/data/hw_data.csv', index_col=0)
phoneNumbers = []
for i in Notes_list:
  indiv =  i.split()
  if "Phone" in i:
    for j in range(len(indiv)):
      if "Phone" in indiv[j]:
        temp = ""
        for d in indiv[j+1]:
          if d.isdigit():
            temp += d
            if len(temp) == 10:
              phoneNumbers.append(temp)
              break
        # print(temp)
        break
  else:
      phoneNumbers.append(None)

print(phoneNumbers)
# Out:
# [None, '0011864445', None, None, '9298784923', '8400434845', '1205772777', '7732298494', None, '3855702012', '8335001622', None, None, None, '1926717329', None, '1472406850', '0890809619', None, None, '7613320360', '0496127422', '2658140124', '1235236661', '1750853068', '9344098856', None, '1602527069', None, '0013056206', '6326767227', None, None, None, '1384296504', '0013878874', None, None, None, '8476853886', '8873818992', '6995024108', '1522656972', None, None, '0019055135', None, None, '1140134227', None, '6422722841', None, None, '5213474286', '0015945955', None, '3958221859', '6376602039', None, None, None, None, '6883681099', '0489588184', '4759985647', None, None, '7736330634', None, None, None, '1444552862', '7745601177', '6723458946', '2760403296', None, '2181199190', '5237374958', None, '7572927242', None, '9924844292', '0326874150', None, '0013244132', '0245721767', None, None, None, None, '4377596763', '4867843574', None, '3309547452', None, None, None, '7416971770', '
# ...

# %%
df["Phone"] = pd.Series(phoneNumbers)

# %%
df
# Out:
#                               email  \
# 0          fosterjennifer@gmail.com
# 1         vanessastephens@gmail.com
# 2                  vsmith@yahoo.com
# 3             tammymorgan@gmail.com
# 4     kimberlylyons@mason-solis.biz
# ...                             ...
# 1995           linblake@hotmail.com
# 1996             xgriffin@gmail.com
# 1997   alexanderrodriguez@smith.com
# 1998            wwilliams@yahoo.com
# 1999              brent46@gmail.com
#
#                                                   notes       Phone
# 0                  st Dt February 2005 ed dt;10/27/2011        None
# 1     st date:1974-05-21 end date 06/17/2013 pn:  00...  0011864445
# 2                start dt 01/14/1985-ed date:2021-03-21        None
# 3                      STDT July 1973-end dt 01/20/2012        None
# 4       st date:09/28/2002-ENDT 04/10-p/n  929-878-4923  9298784923
# ...                                                 ...         ...
# ...

# %%
# import pandas as pd 
# from datetime import datetime 
# pd.date_range(start="2018-01-01",end="2018-31-12").to_pydatetime().tolist()

# %%
df
# Out:
#                               email  \
# 0          fosterjennifer@gmail.com
# 1         vanessastephens@gmail.com
# 2                  vsmith@yahoo.com
# 3             tammymorgan@gmail.com
# 4     kimberlylyons@mason-solis.biz
# ...                             ...
# 1995           linblake@hotmail.com
# 1996             xgriffin@gmail.com
# 1997   alexanderrodriguez@smith.com
# 1998            wwilliams@yahoo.com
# 1999              brent46@gmail.com
#
#                                                   notes       Phone
# 0                  st Dt February 2005 ed dt;10/27/2011        None
# 1     st date:1974-05-21 end date 06/17/2013 pn:  00...  0011864445
# 2                start dt 01/14/1985-ed date:2021-03-21        None
# 3                      STDT July 1973-end dt 01/20/2012        None
# 4       st date:09/28/2002-ENDT 04/10-p/n  929-878-4923  9298784923
# ...                                                 ...         ...
# ...

# %%
df['notes'].replace('p/n','Phone',inplace=True)

# %%
Notes_list = []
for i in range(len(df)):
    if 'pn:' in df.iloc[i]['notes']:
        Notes_list.append(df.iloc[i]['notes'].replace('pn:','Phone'))
    elif 'p#' in df.iloc[i]['notes']:
        Notes_list.append(df.iloc[i]['notes'].replace('p#','Phone'))
    elif 'p/n' in df.iloc[i]['notes']:
        Notes_list.append(df.iloc[i]['notes'].replace('p/n', 'Phone'))
    elif 'pn' in df.iloc[i]['notes']:
        Notes_list.append(df.iloc[i]['notes'].replace('pn','Phone'))
    elif 'P#' in df.iloc[i]['notes']:
        Notes_list.append(df.iloc[i]['notes'].replace('P#','Phone'))
    else:
        Notes_list.append(df.iloc[i]['notes'])

# %%
df
# Out:
#                               email  \
# 0          fosterjennifer@gmail.com
# 1         vanessastephens@gmail.com
# 2                  vsmith@yahoo.com
# 3             tammymorgan@gmail.com
# 4     kimberlylyons@mason-solis.biz
# ...                             ...
# 1995           linblake@hotmail.com
# 1996             xgriffin@gmail.com
# 1997   alexanderrodriguez@smith.com
# 1998            wwilliams@yahoo.com
# 1999              brent46@gmail.com
#
#                                                   notes       Phone
# 0                  st Dt February 2005 ed dt;10/27/2011        None
# 1     st date:1974-05-21 end date 06/17/2013 pn:  00...  0011864445
# 2                start dt 01/14/1985-ed date:2021-03-21        None
# 3                      STDT July 1973-end dt 01/20/2012        None
# 4       st date:09/28/2002-ENDT 04/10-p/n  929-878-4923  9298784923
# ...                                                 ...         ...
# ...

# %%
Phone_list = []
for i in Notes_list:
    if "Phone" in i:
        i = i.replace(' ',"")
        for j in i:
            if j.isdigit():
                Phone_list.append(i.split("Phone")[1][:15])
    else:
        Phone_list.append("None")

# %%
Phone_list
# Out:
# ['None',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  '001-186-444-558',
#  'None',
#  'None',
#  '929-878-4923',
#  '929-878-4923',
#  '929-878-4923',
#  '929-878-4923',
#  '929-878-4923',
#  '929-878-4923',
#  '929-878-4923',
#  '929-878-4923',
#  '929-878-4923',
#  '929-878-4923',
#  '929-878-4923',
#  '929-878-4923',
#  '929-878-4923',
# ...

# %%
date_list = []
for i in range(len(df)):
    if 'statedate' in df.iloc[i]['notes']:
        date_list.append(df.iloc[i]['notes'].replace('statedate','startdate'))
    elif 'st Dt' in df.iloc[i]['notes']:
        date_list.append(df.iloc[i]['notes'].replace('st Dt','startdate'))
    elif 'st date' in df.iloc[i]['notes']:
        date_list.append(df.iloc[i]['notes'].replace('st date','startdate'))
    elif 'start dt' in df.iloc[i]['notes']:
        date_list.append(df.iloc[i]['notes'].replace('start dt', 'statedate'))
    elif 'STDT' in df.iloc[i]['notes']:
        date_list.append(df.iloc[i]['notes'].replace('STDT','startdate'))
    elif 'st dt' in df.iloc[i]['notes']:
        date_list.append(df.iloc[i]['notes'].replace('st dt','startdate'))
    elif 'start date' in df.iloc[i]['notes']:
        date_list.append(df.iloc[i]['notes'].replace('start date','startdate'))
    else:
        date_list.append(df.iloc[i]['notes'])

# %%
date_list=[i.replace('statedate','startdate') for i in date_list]

# %%
date_list
# Out:
# ['startdate February 2005 ed dt;10/27/2011',
#  'startdate:1974-05-21 end date 06/17/2013 pn:  001-186-444-5580x968',
#  'startdate 01/14/1985-ed date:2021-03-21',
#  'startdate July 1973-end dt 01/20/2012',
#  'startdate:09/28/2002-ENDT 04/10-p/n  929-878-4923',
#  'startdate 2001-04 ENDT 2013-04 p#  8400434845',
#  'pn:  120-577-2777-startdate June 1980-ENDT 2017-01',
#  'p/n  773.229.8494/startdate 1998-06/end Dt 03/21',
#  'startdate 1986/ENDT 03/18/2014',
#  'startdate 08/89 ed date:March 2019 p#  3855702012',
#  'pn: 833-500-1622x21862 startdate:10/08/1973 ed date:06/11',
#  'startdate 1991-08-ed date:2021-08-14',
#  'startdate 05/29/1979-end dt 2021-11-01',
#  'startdate 1975-en dt:12/20/2012',
#  'startdate 07/11/1989-end date 10/12-pn:  +1-926-717-3290x3105',
#  'startdate:August 2000 en dt:2010-12',
#  'startdate 09/16/2007-ENDT 2018-07-pn: +1-472-406-8509x747',
#  'startdate 05/15/2006 end dt 2014-05-24 pn:  (089)080-9619x72039',
#  'startdate 05/08/end date 2010-09-11',
# ...

# %%
date_list=[i.lower() for i in date_list]

# %%
end_date_list = []
for i in date_list:
    if 'ed dt;' in i:
        end_date_list.append(i.replace('ed dt;','enddate'))
    elif 'ed date:' in i:
        end_date_list.append(i.replace('ed date:','enddate'))
    elif 'end dt' in i:
        end_date_list.append(i.replace('end dt', 'enddate'))
    elif 'endt' in i:
        end_date_list.append(i.replace('endt','enddate'))
    elif 'en dt' in i:
        end_date_list.append(i.replace('en dt','enddate'))
    elif 'end date' in i:
        end_date_list.append(i.replace('end date','enddate'))
    
    else:
        end_date_list.append(i)

# %%
end_date_list=[i.replace(':',' ') for i in end_date_list]

# %%
end_date_list
# Out:
# ['startdate february 2005 enddate10/27/2011',
#  'startdate 1974-05-21 enddate 06/17/2013 pn   001-186-444-5580x968',
#  'startdate 01/14/1985-enddate2021-03-21',
#  'startdate july 1973-enddate 01/20/2012',
#  'startdate 09/28/2002-enddate 04/10-p/n  929-878-4923',
#  'startdate 2001-04 enddate 2013-04 p#  8400434845',
#  'pn   120-577-2777-startdate june 1980-enddate 2017-01',
#  'p/n  773.229.8494/startdate 1998-06/enddate 03/21',
#  'startdate 1986/enddate 03/18/2014',
#  'startdate 08/89 enddatemarch 2019 p#  3855702012',
#  'pn  833-500-1622x21862 startdate 10/08/1973 enddate06/11',
#  'startdate 1991-08-enddate2021-08-14',
#  'startdate 05/29/1979-enddate 2021-11-01',
#  'startdate 1975-enddate 12/20/2012',
#  'startdate 07/11/1989-enddate 10/12-pn   +1-926-717-3290x3105',
#  'startdate august 2000 enddate 2010-12',
#  'startdate 09/16/2007-enddate 2018-07-pn  +1-472-406-8509x747',
#  'startdate 05/15/2006 enddate 2014-05-24 pn   (089)080-9619x72039',
# ...

# %%
start=[]
for i in end_date_list:
    if 'startdate' in i and 'enddate' in i:
        start.append(i.split('startdate')[1].split('enddate')[0])
    else:
        start.append(i)

# %%
len(start)
# Out:
# 2000

# %%
for i in range(len(end_date_list)):
    if 'pn:' in end_date_list[i]:
        end_date_list[i]=end_date_list[i].replace('pn:','Phone')
    elif 'p#' in end_date_list[i]:
        end_date_list[i]=end_date_list[i].replace('p#','Phone')
    elif 'p/n' in end_date_list[i]:
        end_date_list[i]=end_date_list[i].replace('p/n', 'Phone')
    elif 'pn' in end_date_list[i]:
        end_date_list[i]=end_date_list[i].replace('pn','Phone')
    elif 'P#' in end_date_list[i]:
        end_date_list[i]=end_date_list[i].replace('P#','Phone')
    else:
        end_date_list[i]=end_date_list[i]

# %%
end_date_list
# Out:
# ['startdate february 2005 enddate10/27/2011',
#  'startdate 1974-05-21 enddate 06/17/2013 Phone   001-186-444-5580x968',
#  'startdate 01/14/1985-enddate2021-03-21',
#  'startdate july 1973-enddate 01/20/2012',
#  'startdate 09/28/2002-enddate 04/10-Phone  929-878-4923',
#  'startdate 2001-04 enddate 2013-04 Phone  8400434845',
#  'Phone   120-577-2777-startdate june 1980-enddate 2017-01',
#  'Phone  773.229.8494/startdate 1998-06/enddate 03/21',
#  'startdate 1986/enddate 03/18/2014',
#  'startdate 08/89 enddatemarch 2019 Phone  3855702012',
#  'Phone  833-500-1622x21862 startdate 10/08/1973 enddate06/11',
#  'startdate 1991-08-enddate2021-08-14',
#  'startdate 05/29/1979-enddate 2021-11-01',
#  'startdate 1975-enddate 12/20/2012',
#  'startdate 07/11/1989-enddate 10/12-Phone   +1-926-717-3290x3105',
#  'startdate august 2000 enddate 2010-12',
#  'startdate 09/16/2007-enddate 2018-07-Phone  +1-472-406-8509x747',
# ...

# %%
end_date_list[1].split('enddate')[-1].split('Phone')[0]
# Out:
# ' 06/17/2013 '

# %%
end=[]
for i in end_date_list:
    if 'Phone' in i.split('enddate')[-1]:
        end.append(i.split('enddate')[-1].split('Phone')[0])
    else:
        end.append(i.split('enddate')[-1])

# %%
end
# Out:
# ['10/27/2011',
#  ' 06/17/2013 ',
#  '2021-03-21',
#  ' 01/20/2012',
#  ' 04/10-',
#  ' 2013-04 ',
#  ' 2017-01',
#  ' 03/21',
#  ' 03/18/2014',
#  'march 2019 ',
#  '06/11',
#  '2021-08-14',
#  ' 2021-11-01',
#  ' 12/20/2012',
#  ' 10/12-',
#  ' 2010-12',
#  ' 2018-07-',
#  ' 2014-05-24 ',
#  ' 2010-09-11',
#  ' 2021-07',
#  ' 2021-01/',
#  '09/11/2011',
#  ' 03/31/2019',
#  ' december 2010',
#  ' 2010-05-01 ',
#  '2014/',
#  ' 2017-07',
#  ' 05/11 ',
#  ' october 2020',
#  ' 02/18',
#  ' 2018',
#  ' 2015',
#  'may 2013',
#  ' 08/11',
#  ' march 2016',
#  ' february 2018-',
#  '2020-04-01',
#  ' 2016-12-03',
#  '2011',
#  '2015-08-28',
#  ' 2011-10',
#  ' 2018-06/',
#  ' 02/19/2015',
#  ' 2018-08',
#  ' 05/22/2012',
#  ' 04/16/',
#  '2015',
#  ' 2011-12-17',
#  '04/15',
#  '03/21',
#  ' september 2013-',
#  ' 2017',
#  ' 11/22/2016',
#  ' april 2019',
#  ' june 2014/',
#  ' 2013-09',
#  ' 11/17/2011-',
#  ' 02/19/2012-',
#  ' 2012-01-25',
#  '2013-09',
#  '2012',
#  ' 12/12',
# ...

# %%
df['start date']=start

# %%
df['end date']=end

# %%
df
# Out:
#                               email  \
# 0          fosterjennifer@gmail.com
# 1         vanessastephens@gmail.com
# 2                  vsmith@yahoo.com
# 3             tammymorgan@gmail.com
# 4     kimberlylyons@mason-solis.biz
# ...                             ...
# 1995           linblake@hotmail.com
# 1996             xgriffin@gmail.com
# 1997   alexanderrodriguez@smith.com
# 1998            wwilliams@yahoo.com
# 1999              brent46@gmail.com
#
#                                                   notes       Phone  \
# 0                  st Dt February 2005 ed dt;10/27/2011        None
# 1     st date:1974-05-21 end date 06/17/2013 pn:  00...  0011864445
# 2                start dt 01/14/1985-ed date:2021-03-21        None
# 3                      STDT July 1973-end dt 01/20/2012        None
# 4       st date:09/28/2002-ENDT 04/10-p/n  929-878-4923  9298784923
# ...                                                 ...         ...
# ...

# %%
from dateutil import parser

# %%
repalce_variable=[]
for i in df[df['start date'].str.contains('/00', na=False)]['start date']:
    repalce_variable.append(i)

# %%
repalce_variable
# Out:
# [' 11/00/',
#  ' 03/00 ',
#  ' 05/00-',
#  ' 11/00/',
#  ' 12/00-',
#  ' 08/00-',
#  ' 09/00-',
#  ';06/00 ']

# %%
for i in repalce_variable:
    df['start date']=df['start date'].replace(i,i.split('/')[0]+'/2000')

# %%
startdt=[]
for i in df['start date']:
    try:
        if parser.parse(i):
            startdt.append(parser.parse(i))
    except:
        if i != 'NA':
            startdt.append(parser.parse(i[0:-1]))
        else:
            startdt.append(np.NAN)

# %% [markdown]
# # start.replace(' 03/00 ','NA')
# start.replace(' 11/00/ ','NA')

# %%
startdt
# Out:
# [datetime.datetime(2005, 2, 12, 0, 0),
#  datetime.datetime(1974, 5, 21, 0, 0),
#  datetime.datetime(1985, 1, 14, 0, 0),
#  datetime.datetime(1973, 7, 12, 0, 0),
#  datetime.datetime(2002, 9, 28, 0, 0),
#  datetime.datetime(2001, 4, 12, 0, 0),
#  datetime.datetime(1980, 6, 12, 0, 0),
#  datetime.datetime(1998, 6, 12, 0, 0),
#  datetime.datetime(1986, 11, 12, 0, 0),
#  datetime.datetime(1989, 8, 12, 0, 0),
#  datetime.datetime(1973, 10, 8, 0, 0),
#  datetime.datetime(1991, 8, 12, 0, 0),
#  datetime.datetime(1979, 5, 29, 0, 0),
#  datetime.datetime(1975, 11, 12, 0, 0),
#  datetime.datetime(1989, 7, 11, 0, 0),
#  datetime.datetime(2000, 8, 12, 0, 0),
#  datetime.datetime(2007, 9, 16, 0, 0),
#  datetime.datetime(2006, 5, 15, 0, 0),
#  datetime.datetime(2021, 5, 8, 0, 0),
#  datetime.datetime(1999, 11, 12, 0, 0),
#  datetime.datetime(1971, 5, 12, 0, 0),
#  datetime.datetime(1992, 11, 12, 0, 0),
#  datetime.datetime(1987, 11, 12, 0, 0),
#  datetime.datetime(1996, 8, 12, 0, 0),
# ...

# %%
enddt=[]
for i in df['end date']:
    try:
        if parser.parse(i):
            enddt.append(parser.parse(i))
    except:
        if i != 'NA':
            enddt.append(parser.parse(i[0:-1]))
        else:
            enddt.append(np.NAN)

# %%
enddt
# Out:
# [datetime.datetime(2011, 10, 27, 0, 0),
#  datetime.datetime(2013, 6, 17, 0, 0),
#  datetime.datetime(2021, 3, 21, 0, 0),
#  datetime.datetime(2012, 1, 20, 0, 0),
#  datetime.datetime(2021, 4, 10, 0, 0),
#  datetime.datetime(2013, 4, 12, 0, 0),
#  datetime.datetime(2017, 1, 12, 0, 0),
#  datetime.datetime(2021, 3, 21, 0, 0),
#  datetime.datetime(2014, 3, 18, 0, 0),
#  datetime.datetime(2019, 3, 12, 0, 0),
#  datetime.datetime(2021, 6, 11, 0, 0),
#  datetime.datetime(2021, 8, 14, 0, 0),
#  datetime.datetime(2021, 11, 1, 0, 0),
#  datetime.datetime(2012, 12, 20, 0, 0),
#  datetime.datetime(2021, 10, 12, 0, 0),
#  datetime.datetime(2010, 12, 12, 0, 0),
#  datetime.datetime(2018, 7, 12, 0, 0),
#  datetime.datetime(2014, 5, 24, 0, 0),
#  datetime.datetime(2010, 9, 11, 0, 0),
#  datetime.datetime(2021, 7, 12, 0, 0),
#  datetime.datetime(2021, 1, 12, 0, 0),
#  datetime.datetime(2011, 9, 11, 0, 0),
#  datetime.datetime(2019, 3, 31, 0, 0),
#  datetime.datetime(2010, 12, 12, 0, 0),
# ...

# %%
df['start date']=startdt

# %%
df['end date']=enddt

# %%
df
# Out:
#                               email  \
# 0          fosterjennifer@gmail.com
# 1         vanessastephens@gmail.com
# 2                  vsmith@yahoo.com
# 3             tammymorgan@gmail.com
# 4     kimberlylyons@mason-solis.biz
# ...                             ...
# 1995           linblake@hotmail.com
# 1996             xgriffin@gmail.com
# 1997   alexanderrodriguez@smith.com
# 1998            wwilliams@yahoo.com
# 1999              brent46@gmail.com
#
#                                                   notes       Phone  \
# 0                  st Dt February 2005 ed dt;10/27/2011        None
# 1     st date:1974-05-21 end date 06/17/2013 pn:  00...  0011864445
# 2                start dt 01/14/1985-ed date:2021-03-21        None
# 3                      STDT July 1973-end dt 01/20/2012        None
# 4       st date:09/28/2002-ENDT 04/10-p/n  929-878-4923  9298784923
# ...                                                 ...         ...
# ...

# %%
from dateutil.relativedelta import relativedelta
difference_in_years=[]
for i in range(0,len(df)):
    difference_in_years.append(abs(relativedelta(df['end date'].iloc[i], df['start date'].iloc[i]).years))

# %%
difference_in_years
# Out:
# [6,
#  39,
#  36,
#  38,
#  18,
#  12,
#  36,
#  22,
#  27,
#  29,
#  47,
#  30,
#  42,
#  37,
#  32,
#  10,
#  10,
#  8,
#  10,
#  21,
#  49,
#  18,
#  31,
#  14,
#  34,
#  14,
#  33,
#  45,
#  15,
#  40,
#  45,
#  44,
#  6,
#  22,
#  25,
#  25,
#  23,
#  33,
#  15,
#  35,
#  8,
#  30,
#  25,
#  37,
#  16,
#  22,
#  35,
#  25,
#  19,
#  42,
#  18,
#  26,
#  16,
#  39,
#  33,
#  4,
#  28,
#  25,
#  36,
#  12,
#  39,
#  27,
#  17,
#  28,
#  24,
#  20,
#  32,
#  48,
#  30,
#  6,
#  16,
#  1,
#  37,
#  44,
#  43,
#  24,
#  32,
#  47,
#  33,
#  11,
#  0,
#  29,
#  20,
#  27,
#  9,
#  48,
#  34,
#  18,
#  47,
#  28,
#  24,
#  41,
#  34,
#  44,
#  37,
#  23,
#  11,
#  44,
#  40,
#  25,
#  39,
#  9,
#  14,
#  40,
#  47,
#  22,
#  6,
#  42,
#  30,
#  12,
#  27,
#  28,
#  24,
#  12,
#  2,
#  36,
#  26,
#  21,
#  48,
#  16,
#  31,
#  21,
#  12,
#  13,
#  8,
#  35,
#  36,
#  22,
#  13,
#  31,
#  47,
#  2,
#  26,
#  28,
#  4,
#  25,
#  39,
#  34,
#  31,
#  26,
#  32,
#  31,
#  43,
#  22,
#  11,
# ...

# %%
df['duration']=difference_in_years

# %%
df
# Out:
#                               email  \
# 0          fosterjennifer@gmail.com
# 1         vanessastephens@gmail.com
# 2                  vsmith@yahoo.com
# 3             tammymorgan@gmail.com
# 4     kimberlylyons@mason-solis.biz
# ...                             ...
# 1995           linblake@hotmail.com
# 1996             xgriffin@gmail.com
# 1997   alexanderrodriguez@smith.com
# 1998            wwilliams@yahoo.com
# 1999              brent46@gmail.com
#
#                                                   notes       Phone  \
# 0                  st Dt February 2005 ed dt;10/27/2011        None
# 1     st date:1974-05-21 end date 06/17/2013 pn:  00...  0011864445
# 2                start dt 01/14/1985-ed date:2021-03-21        None
# 3                      STDT July 1973-end dt 01/20/2012        None
# 4       st date:09/28/2002-ENDT 04/10-p/n  929-878-4923  9298784923
# ...                                                 ...         ...
# ...
